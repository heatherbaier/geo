# %%
import geopandas as gpd
import pandas as pd
import shutil
import os

from utils import *
# Out:
# /Users/heatherbaier/opt/anaconda3/envs/caoep/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
# Fetch and read the datasets
DATA_PATH = "../../data/KHM/"
khm_schools = gpd.read_file("/Users/heatherbaier/Documents/geo/data/KHM/2012/Basic information of school (2012)/school_of_cambodia_4326.shp")
khm_schools = khm_schools.to_crs("epsg:4326")


# khm_schools["longitude"] = khm_schools.geometry.x
# khm_schools["latitude"] = khm_schools.geometry.y
# khm_schools = khm_schools[["SCHOOL_COD", "SCHOOL_NAM", "longitude", "latitude"]]
# khm_schools.columns = ["deped_id", "school_name", "longitude", "latitude"]
khm_schools.head()
# Out:
#            PROVINCE    SCHOOL_COD        COMMUNE       DISTRICT  \
# 0  Banteay Meanchey  1.020101e+09  Banteay Neang  Mongkol Borei
# 1  Banteay Meanchey  1.020103e+09  Banteay Neang  Mongkol Borei
# 2  Banteay Meanchey  1.020104e+09  Banteay Neang  Mongkol Borei
# 3  Banteay Meanchey  1.020105e+09  Banteay Neang  Mongkol Borei
# 4  Banteay Meanchey  1.020106e+09  Banteay Neang  Mongkol Borei
#
#       SCHOOL_NAM        VILLAGE  SCHOOL_TYP  TYPE_CODE  CLASSES  ROOMS  \
# 0         O Thom         O Thom     Primary        2.0      1.0    1.0
# 1  Banteay Neang  Banteay Neang     Primary        2.0     17.0    9.0
# 2  Banteay Neang  Banteay Neang  Pre school        1.0      4.0    4.0
# 3          Trang          Trang     Primary        2.0      1.0    1.0
# 4        Pongror        Pongror     Primary        2.0      6.0    3.0
#
#   Location  Teach_staf  Non_teach  Enrol                    geometry
# 0    Rural           1          0     29  POINT (103.03070 13.51528)
# 1    Rural          21          3    638  POINT (103.01544 13.51285)
# 2    Urban           4          1    115  POINT (103.01544 13.51285)
# 3    Rural           1          0     26  POINT (103.00795 13.50579)
# 4    Rural           4          1    182  POINT (102.99878 13.49859)

# %%
# Fetch and read the datasets
DATA_PATH = "../../data/KHM/"
khm_schools = gpd.read_file("/Users/heatherbaier/Documents/geo/data/KHM/2014/Basic information of school (2014)/basic_information_of_school_2014.shp")
khm_schools = khm_schools.to_crs("epsg:4326")


# khm_schools["longitude"] = khm_schools.geometry.x
# khm_schools["latitude"] = khm_schools.geometry.y
# khm_schools = khm_schools[["SCHOOL_COD", "SCHOOL_NAM", "longitude", "latitude"]]
# khm_schools.columns = ["deped_id", "school_name", "longitude", "latitude"]
khm_schools.head()
# Out:
#            PROVINCE    SCHOOL_COD        COMMUNE       DISTRICT  \
# 0  Banteay Meanchey  1.020101e+09  Banteay Neang  Mongkol Borei
# 1  Banteay Meanchey  1.020103e+09  Banteay Neang  Mongkol Borei
# 2  Banteay Meanchey  1.020105e+09  Banteay Neang  Mongkol Borei
# 3  Banteay Meanchey  1.020106e+09  Banteay Neang  Mongkol Borei
# 4  Banteay Meanchey  1.020107e+09  Banteay Neang  Mongkol Borei
#
#       SCHOOL_NAM        VILLAGE SCHOOL_TYP Location  SHIFTS  DISADV  ...  Sex  \
# 0         O Thom         O Thom    Primary    Rural     1.0     0.0  ...    M
# 1  Banteay Neang  Banteay Neang    Primary    Rural     2.0     0.0  ...    M
# 2          Trang          Trang    Primary    Rural     1.0     1.0  ...    M
# 3        Pongror        Pongror    Primary    Rural     2.0     0.0  ...    M
# 4   Kauk Tunloap   Kauk Tunloap    Primary    Rural     2.0     0.0  ...    F
#
#    Total_Teac  Female_Tec  Total_Non_  Female_Non  Total_enro  Female_Enr  \
# 0           2           0           2           0          47          21
# 1          20          15           4           1         562         279
# 2           1           1           0           0          23           6
# 3           3           1           1           0         155          73
# 4           5           2           1           1         186          93
#
#    Total_clas  Total_Staf                    geometry
# 0           2           4  POINT (103.03070 13.51528)
# 1          16          24  POINT (103.01544 13.51285)
# 2           1           1  POINT (103.00795 13.50579)
# 3           6           4  POINT (102.99878 13.49859)
# 4           6           6  POINT (103.01424 13.48958)
#
# [5 rows x 106 columns]

# %%
khm_schools.columns
# Out:
# Index(['PROVINCE', 'SCHOOL_COD', 'COMMUNE', 'DISTRICT', 'SCHOOL_NAM',
#        'VILLAGE', 'SCHOOL_TYP', 'Location', 'SHIFTS', 'DISADV',
#        ...
#        'Sex', 'Total_Teac', 'Female_Tec', 'Total_Non_', 'Female_Non',
#        'Total_enro', 'Female_Enr', 'Total_clas', 'Total_Staf', 'geometry'],
#       dtype='object', length=106)

# %%
lycee_2012 = pd.read_csv("/Users/heatherbaier/Documents/geo/data/KHM/2012/lyceecollege.csv")
lycee_2012.head()
# Out:
#              X            Y          PROVINCE      map_id        COMMUNE  \
# 0  286263.7732  1491970.086  Banteay Meanchey  1020109710  Banteay Neang
# 1  281984.7480  1494941.116  Banteay Meanchey  1020203708      Bat Trang
# 2  276018.6830  1484873.055  Banteay Meanchey  1020309904        Chamnom
# 3  293983.8258  1489970.055  Banteay Meanchey  1020403709   Kauk Balaing
# 4  292275.8310  1498734.123  Banteay Meanchey  1020501706       Koy Meng
#
#         DISTRICT SCHOOL_NAM              VILLAGE   SCHOOL_TYP  TYPE_CODE  \
# 0  Mongkol Borei     Khilek               Khilek      College          3
# 1  Mongkol Borei  Bat Trang  Anlung Thngann Lech      College          3
# 2  Mongkol Borei   Raung Ko        Peam Raung Ko  Lycee G7-12          5
# 3  Mongkol Borei      Ta An         Pralay Chrey      College          3
# 4  Mongkol Borei   Koy Meng             Koy Meng      College          3
#
#    CLASSES  ROOMS Location  Teach_staf  Non_teach  Enrol
# 0        6      5    Rural          16          3    286
# 1        6      5    Rural          16          3    267
# 2       20     20    Rural          44          6    798
# 3        6      5    Rural           9          5    285
# 4        6     11    Rural          21          3    291

# %%
lycee_2012.shape
# Out:
# (1615, 16)

# %%
khm_schools["SCHOOL_TYP"].unique()
# Out:
# array(['Primary', 'Pre school', 'College', 'Lycee G7-12', 'Lycee G10-12'],
#       dtype=object)

# %%
khm_schools[khm_schools["SCHOOL_TYP"] == "College"]
# Out:
#                PROVINCE    SCHOOL_COD        COMMUNE         DISTRICT  \
# 2657   Banteay Meanchey  1.020110e+09  Banteay Neang    Mongkol Borei
# 2662   Banteay Meanchey  1.020204e+09      Bat Trang    Mongkol Borei
# 2670   Banteay Meanchey  1.020404e+09   Kauk Balaing    Mongkol Borei
# 2675   Banteay Meanchey  1.020502e+09       Koy Meng    Mongkol Borei
# 2683   Banteay Meanchey  1.020610e+09       O Prasat    Mongkol Borei
# ...                 ...           ...            ...              ...
# 10960    Otdar Meanchey  2.405060e+10    Tumnup Dach  Trapaing Prasat
# 10963             Takeo  2.104040e+10        Kampeng        Kiri Vong
# 10965             Takeo  2.109061e+10        O Saray          Tramkak
# 10966             Takeo  2.110041e+10          Khvav           Traing
# 10981    Otdar Meanchey  2.402011e+10          Ampil    Banteay Ampil
#
#               SCHOOL_NAM              VILLAGE SCHOOL_TYP Location  SHIFTS  \
# 2657              Khilek               Khilek    College    Rural     0.0
# 2662           Bat Trang  Anlung Thngann Lech    College    Rural     0.0
# 2670               Ta An         Pralay Chrey    College    Rural     0.0
# 2675            Koy Meng             Koy Meng    College    Rural     0.0
# 2683            O Snguot             O Snguot    College    Rural     0.0
# ...                  ...                  ...        ...      ...     ...
# 10960        Tumnup Dach           Chey Niwat    College    Rural     0.0
# 10963       Sok An Phnom            Wat Phnom    College    Rural     0.0
# 10965  Hun Sen Tnot Chum            Tnot Chum    College    Rural     0.0
# 10966          Srey Sith              Ta Sren    College    Rural     0.0
# 10981              Ampil           Ampil Chas    College    Rural     0.0
#
#        DISADV  ...   Sex  Total_Teac  Female_Tec  Total_Non_  Female_Non  \
# 2657      0.0  ...     M          12           4           4           3
# 2662      0.0  ...     F          16          11           4           3
# 2670      0.0  ...     M           9           6           3           1
# 2675      0.0  ...     F          14           7           6           2
# 2683      0.0  ...     M          16           9           5           4
# ...       ...  ...   ...         ...         ...         ...         ...
# 10960     0.0  ...     M           8           2           0           0
# 10963     0.0  ...  None           0           0           0           0
# 10965     0.0  ...  None           0           0           0           0
# 10966     0.0  ...  None           0           0           0           0
# 10981     0.0  ...  None           0           0           0           0
#
#        Total_enro  Female_Enr  Total_clas  Total_Staf  \
# 2657          281         151           7          16
# 2662          211         106           5          20
# 2670          215         118           6          12
# 2675          261         144           6          20
# 2683          298         168           7          21
# ...           ...         ...         ...         ...
# 10960         201          85           4           8
# 10963        None        None           0           0
# 10965        None        None           0           0
# 10966        None        None           0           0
# 10981        None        None           0           0
#
#                          geometry
# 2657   POINT (103.02544 13.48807)
# 2662   POINT (102.98570 13.51461)
# 2670   POINT (103.09687 13.47055)
# 2675   POINT (103.08047 13.54963)
# 2683   POINT (103.01129 13.46691)
# ...                           ...
# 10960  POINT (104.43080 14.28270)
# 10963  POINT (104.72548 10.65249)
# 10965  POINT (104.53086 11.06693)
# 10966  POINT (104.73294 10.90822)
# 10981  POINT (103.11523 14.23811)
#
# [1191 rows x 106 columns]

# %%
print([i for i in khm_schools.columns])
# Out:
# ['PROVINCE', 'SCHOOL_COD', 'COMMUNE', 'DISTRICT', 'SCHOOL_NAM', 'VILLAGE', 'SCHOOL_TYP', 'Location', 'SHIFTS', 'DISADV', 'SWATER', 'STOILET', 'PAEXIST', 'G1T', 'G1F', 'G2T', 'G2F', 'G3T', 'G3F', 'G4T', 'G4F', 'G5T', 'G5F', 'G6T', 'G6F', 'G1RT', 'G1RF', 'G2RT', 'G2RF', 'G3RT', 'G3RF', 'G4RT', 'G4RF', 'G5RT', 'G5RF', 'G6RT', 'G6RF', 'PINTAKET', 'PINTAKEF', 'POVERT', 'POVERF', 'TCHT', 'TCHF', 'NTCHT', 'NTCHF', 'NOTRAIN', 'CONTRACT', 'COMTEACH', 'NUMMONKS', 'BUILDS', 'ROOMS', 'CLROOMS', 'CLASSWFL', 'CLASSWRF', 'CLWGWALL', 'NWDESK', 'NWCHAIR', 'NWBOARD', 'NWTTBCH', 'PROMG1T', 'REPRG1T', 'DROPG1T', 'PROMG1F', 'REPRG1F', 'DROPG1F', 'PROMG2T', 'REPRG2T', 'DROPG2T', 'PROMG2F', 'REPRG2F', 'DROPG2F', 'PROMG3T', 'REPRG3T', 'DROPG3T', 'PROMG3F', 'REPRG3F', 'DROPG3F', 'PROMG4T', 'REPRG4T', 'DROPG4T', 'PROMG4F', 'REPRG4F', 'DROPG4F', 'PROMG5T', 'REPRG5T', 'DROPG5T', 'PROMG5F', 'REPRG5F', 'DROPG5F', 'PROMG6T', 'REPRG6T', 'DROPG6T', 'PROMG6F', 'REPRG6F', 'DROPG6F', 'School_Pri', 'Sex', 'Total_Teac', 'Female_Tec', 'Total_Non_', 'Female_Non', 'Total_enro', 'Female_Enr', 'Total_clas', 'Total_Staf', 'geometry']
