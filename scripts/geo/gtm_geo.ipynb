# %%
import geopandas as gpd
import pandas as pd
import shutil
import os

from utils import *

# %%
# import all data
gua_1314 = pd.read_excel("../../data/GTM/establecimientos_2013-2014.xlsx")
print("1")
gua_1516 = pd.read_excel("../../data/GTM/establecimientos_2015-2016.xlsx")
print("2")
gua_1718 = pd.read_excel("../../data/GTM/establecimientos_2017-2018.xlsx")
print("3")
gua_1920 = pd.read_excel("../../data/GTM/establecimientos_2019-2020.xlsx")
print("4")
gua_2122 = pd.read_excel("../../data/GTM/establecimientos_2021-2022.xlsx")
print("5")

# combine into one dataframe
gua_all = pd.concat([gua_1314, gua_1516, gua_1718, gua_1920, gua_2122])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
gua_all
# Out:
#        CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                    1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                    1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 2                    1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                    1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 4                    1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# ...                ...          ...      ...        ...            ...
# 99738               22      JUTIAPA       17    QUESADA  22-17-2536-42
# 99739               22      JUTIAPA       17    QUESADA  22-17-2537-42
# 99740               22      JUTIAPA       17    QUESADA  22-17-2537-42
# 99741               22      JUTIAPA       17    QUESADA  22-17-2538-42
# 99742               22      JUTIAPA       17    QUESADA  22-17-2538-42
#
#                      NombreEstablecimiento  \
# 0      EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1              EODP NO.21 GABRIELA MISTRAL
# 2              EODP NO.21 GABRIELA MISTRAL
# 3                EODP NO. 36 LA PRESIDENTA
# 4                EODP NO. 36 LA PRESIDENTA
# ...                                    ...
# 99738                    EODP ANEXA A EORM
# 99739                    EODP ANEXA A EORM
# 99740                    EODP ANEXA A EORM
# 99741                    EODP ANEXA A EORM
# 99742                    EODP ANEXA A EORM
#
#                                                direccion       Tel  \
# 0                                         19 CALLE 12-71  22324443
# 1                                         19 CALLE 12-71  22324443
# 2                                         19 CALLE 12-71  22324443
# 3      2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 4      2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# ...                                                  ...       ...
# 99738                                   ALDEA BORDO ALTO       NaN
# 99739                                 ALDEA SAN FERNANDO  58093958
# 99740                                 ALDEA SAN FERNANDO  58093958
# 99741                                  ALDEA POTRERILLOS       NaN
# 99742                                  ALDEA POTRERILLOS       NaN
#
#                              CorreoElectronico        Nivel   Jornada  \
# 0                                          NaN  PREPRIMARIA  MATUTINA
# 1      escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA
# 2      escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA
# 3                             myhb30@gmail.com  PREPRIMARIA  MATUTINA
# 4                             myhb30@gmail.com  PREPRIMARIA  MATUTINA
# ...                                        ...          ...       ...
# 99738                                      NaN  PREPRIMARIA  MATUTINA
# 99739                  sanfernando43@gmail.com  PREPRIMARIA  MATUTINA
# 99740                  sanfernando43@gmail.com  PREPRIMARIA  MATUTINA
# 99741                                      NaN  PREPRIMARIA  MATUTINA
# 99742                                      NaN  PREPRIMARIA  MATUTINA
#
#         Modalidad             Plan    Latitud   Longitud  \
# 0      MONOLINGUE  DIARIO(REGULAR)  14.629704 -90.507466
# 1      MONOLINGUE  DIARIO(REGULAR)  14.629704 -90.507466
# 2      MONOLINGUE  DIARIO(REGULAR)  14.629704 -90.507466
# 3      MONOLINGUE  DIARIO(REGULAR)  14.628374 -90.520804
# 4      MONOLINGUE  DIARIO(REGULAR)  14.628374 -90.520804
# ...           ...              ...        ...        ...
# 99738  MONOLINGUE  DIARIO(REGULAR)  14.245926 -90.047704
# 99739  MONOLINGUE  DIARIO(REGULAR)  14.255079 -90.008671
# 99740  MONOLINGUE  DIARIO(REGULAR)  14.255079 -90.008671
# 99741  MONOLINGUE  DIARIO(REGULAR)  14.255523 -90.055809
# 99742  MONOLINGUE  DIARIO(REGULAR)  14.255523 -90.055809
#
#                                        Año   Sector    Area
# 0                                     2013  OFICIAL  URBANO
# 1                                     2013  OFICIAL  URBANO
# 2                                     2014  OFICIAL  URBANO
# 3                                     2013  OFICIAL  URBANO
# 4                                     2014  OFICIAL  URBANO
# ...                                    ...      ...     ...
# 99738  2022 PRELIMINAR FINAL AL 2023-01-05  OFICIAL   RURAL
# 99739  2021 PRELIMINAR FINAL AL 2022-05-09  OFICIAL   RURAL
# 99740  2022 PRELIMINAR FINAL AL 2023-01-05  OFICIAL   RURAL
# 99741  2021 PRELIMINAR FINAL AL 2022-05-09  OFICIAL   RURAL
# 99742  2022 PRELIMINAR FINAL AL 2023-01-05  OFICIAL   RURAL
#
# [485365 rows x 18 columns]

# %%
gua_all = gua_all[gua_all["Sector"].isin(['OFICIAL', 'MUNICIPAL', 'COOPERATIVA'])]
gua_all = gua_all.drop_duplicates(subset = ["CodigoEst"])
gua_all.head()
# Out:
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 5                1    GUATEMALA        1  GUATEMALA  00-01-0004-42
# 7                1    GUATEMALA        1  GUATEMALA  00-01-0005-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 5        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7             EODP NO.8 OVIDIO DECROLY
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 5                     12 CALLE A 14-56 BARRIO GERONA  22539326
# 7                                     3A CALLE 16-73  22203623
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 5                   anaocifuente@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 7     escuelaovidiodecroly2011@hotmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO
# 5  DIARIO(REGULAR)  14.633863 -90.506875  2013  OFICIAL  URBANO
# 7  DIARIO(REGULAR)  14.643532 -90.500462  2013  OFICIAL  URBANO

# %%
# select and rename relevant columns
gua_all = gua_all[["CodigoEst", "NombreEstablecimiento", "direccion", "Latitud", "Longitud"]]
gua_all.columns = ["deped_id", "school_name", "address", "latitude", "longitude"]
gua_all.head()
# Out:
#         deped_id                          school_name  \
# 0  00-01-0001-42  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1  00-01-0002-42          EODP NO.21 GABRIELA MISTRAL
# 3  00-01-0003-42            EODP NO. 36 LA PRESIDENTA
# 5  00-01-0004-42        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7  00-01-0005-42             EODP NO.8 OVIDIO DECROLY
#
#                                              address   latitude  longitude
# 0                                     19 CALLE 12-71  14.629704 -90.507466
# 1                                     19 CALLE 12-71  14.629704 -90.507466
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  14.628374 -90.520804
# 5                     12 CALLE A 14-56 BARRIO GERONA  14.633863 -90.506875
# 7                                     3A CALLE 16-73  14.643532 -90.500462

# %%
gua_all = gua_all[gua_all["latitude"].notna()]
gua_all = gua_all[gua_all["longitude"].notna()]

gua_all = gua_all[gua_all["latitude"] != 0]
gua_all = gua_all[gua_all["longitude"] != 0]

# %%
gua_all
# Out:
#             deped_id                          school_name  \
# 0      00-01-0001-42  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1      00-01-0002-42          EODP NO.21 GABRIELA MISTRAL
# 3      00-01-0003-42            EODP NO. 36 LA PRESIDENTA
# 5      00-01-0004-42        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7      00-01-0005-42             EODP NO.8 OVIDIO DECROLY
# ...              ...                                  ...
# 28267  06-08-1961-42                    EODP ANEXA A EORM
# 56806  13-07-4941-43                                 EORM
# 66066  14-14-5855-41                    COPB ANEXO A EORM
# 94764  21-02-0073-42                    EODP ANEXA A EORM
# 97463  22-04-2553-42                    EODP ANEXA A EORM
#
#                                                  address   latitude  longitude
# 0                                         19 CALLE 12-71  14.629704 -90.507466
# 1                                         19 CALLE 12-71  14.629704 -90.507466
# 3      2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  14.628374 -90.520804
# 5                         12 CALLE A 14-56 BARRIO GERONA  14.633863 -90.506875
# 7                                         3A CALLE 16-73  14.643532 -90.500462
# ...                                                  ...        ...        ...
# 28267                             CASERIO LOS GUAYABALES  14.115120 -90.320159
# 56806                               ALDEA NUEVA CATARINA  15.776465 -91.786080
# 66066                                        ALDEA XABAJ  15.132827 -90.958704
# 94764               CASERIO LA CAMPANA ALDEA BUENA VISTA  14.781037 -89.817244
# 97463                                   ALDEA EL CARRIZO  14.466765 -89.617751
#
# [23801 rows x 5 columns]

# %%
len(gua_all)
# Out:
# 23801

# %%
352669 / 10
# Out:
# 35266.9

# %%
geo = pd.read_csv("../../files_for_db/geo/gtm_geo.csv")
geo.head()
# Out:
#        geo_id       deped_id                          school_name  \
# 0  GTM-000001  00-01-0001-42  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1  GTM-000002  00-01-0002-42          EODP NO.21 GABRIELA MISTRAL
# 2  GTM-000003  00-01-0003-42            EODP NO. 36 LA PRESIDENTA
# 3  GTM-000004  00-01-0004-42        EODP NO.30 OTILIA NUÑEZ ARIZA
# 4  GTM-000005  00-01-0005-42             EODP NO.8 OVIDIO DECROLY
#
#                                              address adm0       adm1  \
# 0                                     19 CALLE 12-71  GTM  Guatemala
# 1                                     19 CALLE 12-71  GTM  Guatemala
# 2  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  GTM  Guatemala
# 3                     12 CALLE A 14-56 BARRIO GERONA  GTM  Guatemala
# 4                                     3A CALLE 16-73  GTM  Guatemala
#
#         adm2  adm3  longitude   latitude
# 0  Guatemala   NaN -90.507466  14.629704
# 1  Guatemala   NaN -90.507466  14.629704
# 2  Guatemala   NaN -90.520804  14.628374
# 3  Guatemala   NaN -90.506875  14.633863
# 4  Guatemala   NaN -90.500462  14.643532

# %%
# import all data
gua_1314 = pd.read_excel("../../data/GTM/establecimientos_2013-2014.xlsx")
print("1")
gua_1516 = pd.read_excel("../../data/GTM/establecimientos_2015-2016.xlsx")
print("2")
gua_1718 = pd.read_excel("../../data/GTM/establecimientos_2017-2018.xlsx")
print("3")
gua_1920 = pd.read_excel("../../data/GTM/establecimientos_2019-2020.xlsx")
print("4")
gua_2122 = pd.read_excel("../../data/GTM/establecimientos_2021-2022.xlsx")
print("5")

# combine into one dataframe
gua_all = pd.concat([gua_1314, gua_1516, gua_1718, gua_1920, gua_2122])
gua_all.head()
# Out:
# 1
# 2
# 3
# 4
# 5
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 2                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 4                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 2          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 4            EODP NO. 36 LA PRESIDENTA
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 2                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 4  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 2  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 4                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 2  DIARIO(REGULAR)  14.629704 -90.507466  2014  OFICIAL  URBANO
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO
# 4  DIARIO(REGULAR)  14.628374 -90.520804  2014  OFICIAL  URBANO

# %%
gua_all = gua_all[gua_all["Sector"].isin(['OFICIAL', 'MUNICIPAL', 'COOPERATIVA'])]
gua_all = gua_all.drop_duplicates(subset = ["CodigoEst"])
gua_all.head()
# Out:
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 5                1    GUATEMALA        1  GUATEMALA  00-01-0004-42
# 7                1    GUATEMALA        1  GUATEMALA  00-01-0005-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 5        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7             EODP NO.8 OVIDIO DECROLY
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 5                     12 CALLE A 14-56 BARRIO GERONA  22539326
# 7                                     3A CALLE 16-73  22203623
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 5                   anaocifuente@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 7     escuelaovidiodecroly2011@hotmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO
# 5  DIARIO(REGULAR)  14.633863 -90.506875  2013  OFICIAL  URBANO
# 7  DIARIO(REGULAR)  14.643532 -90.500462  2013  OFICIAL  URBANO

# %%
gua_all["Nivel"].unique()
# Out:
# array(['PREPRIMARIA', 'PRIMARIA', 'PRIMARIA DE ADULTOS', 'BASICO',
#        'DIVERSIFICADO', 'INICIAL'], dtype=object)

# %%
gua_all = gua_all[gua_all["Nivel"] != 'PRIMARIA DE ADULTOS']
gua_all.head()
# Out:
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 5                1    GUATEMALA        1  GUATEMALA  00-01-0004-42
# 7                1    GUATEMALA        1  GUATEMALA  00-01-0005-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 5        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7             EODP NO.8 OVIDIO DECROLY
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 5                     12 CALLE A 14-56 BARRIO GERONA  22539326
# 7                                     3A CALLE 16-73  22203623
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 5                   anaocifuente@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 7     escuelaovidiodecroly2011@hotmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO
# 5  DIARIO(REGULAR)  14.633863 -90.506875  2013  OFICIAL  URBANO
# 7  DIARIO(REGULAR)  14.643532 -90.500462  2013  OFICIAL  URBANO

# %%
level_map = {
    "INICIAL": "pre_primary",         # ISCED 0
    "PREPRIMARIA": "pre_primary",     # ISCED 0
    "PRIMARIA": "primary",           # ISCED 1
    "BASICO": "lower_secondary",     # ISCED 2
    "DIVERSIFICADO": "upper_secondary", # ISCED 3
}

gua_all["school_level"] = gua_all["Nivel"].str.strip().str.upper().map(level_map)
gua_all.head()

gua_all.head()
# Out:
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 5                1    GUATEMALA        1  GUATEMALA  00-01-0004-42
# 7                1    GUATEMALA        1  GUATEMALA  00-01-0005-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 5        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7             EODP NO.8 OVIDIO DECROLY
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 5                     12 CALLE A 14-56 BARRIO GERONA  22539326
# 7                                     3A CALLE 16-73  22203623
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 5                   anaocifuente@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 7     escuelaovidiodecroly2011@hotmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area school_level
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO  pre_primary
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO  pre_primary
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO  pre_primary
# 5  DIARIO(REGULAR)  14.633863 -90.506875  2013  OFICIAL  URBANO  pre_primary
# 7  DIARIO(REGULAR)  14.643532 -90.500462  2013  OFICIAL  URBANO  pre_primary

# %%
# Assuming your column is named 'Sector'
gua_all["is_cooperative"] = gua_all["Sector"].str.strip().str.upper().eq("COOPERATIVA")
gua_all.head()
# Out:
#    CodDepartamento Departamento  CodMuni  Municipio      CodigoEst  \
# 0                1    GUATEMALA        1  GUATEMALA  00-01-0001-42
# 1                1    GUATEMALA        1  GUATEMALA  00-01-0002-42
# 3                1    GUATEMALA        1  GUATEMALA  00-01-0003-42
# 5                1    GUATEMALA        1  GUATEMALA  00-01-0004-42
# 7                1    GUATEMALA        1  GUATEMALA  00-01-0005-42
#
#                  NombreEstablecimiento  \
# 0  EODP NO.20 ANTONIO JOSE DE IRISARRI
# 1          EODP NO.21 GABRIELA MISTRAL
# 3            EODP NO. 36 LA PRESIDENTA
# 5        EODP NO.30 OTILIA NUÑEZ ARIZA
# 7             EODP NO.8 OVIDIO DECROLY
#
#                                            direccion       Tel  \
# 0                                     19 CALLE 12-71  22324443
# 1                                     19 CALLE 12-71  22324443
# 3  2A AVE. Y 22 CALLE TERCER NIVEL MERCADO LA PRE...  55161115
# 5                     12 CALLE A 14-56 BARRIO GERONA  22539326
# 7                                     3A CALLE 16-73  22203623
#
#                          CorreoElectronico        Nivel   Jornada   Modalidad  \
# 0                                      NaN  PREPRIMARIA  MATUTINA  MONOLINGUE
# 1  escdeparvulosveinteyveintiuno@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 3                         myhb30@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 5                   anaocifuente@gmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
# 7     escuelaovidiodecroly2011@hotmail.com  PREPRIMARIA  MATUTINA  MONOLINGUE
#
#               Plan    Latitud   Longitud   Año   Sector    Area school_level  \
# 0  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO  pre_primary
# 1  DIARIO(REGULAR)  14.629704 -90.507466  2013  OFICIAL  URBANO  pre_primary
# 3  DIARIO(REGULAR)  14.628374 -90.520804  2013  OFICIAL  URBANO  pre_primary
# 5  DIARIO(REGULAR)  14.633863 -90.506875  2013  OFICIAL  URBANO  pre_primary
# 7  DIARIO(REGULAR)  14.643532 -90.500462  2013  OFICIAL  URBANO  pre_primary
#
#    is_cooperative
# 0           False
# 1           False
# 3           False
# 5           False
# 7           False

# %%
gua_all["is_cooperative"].value_counts()
# Out:
# is_cooperative
# False    37173
# True      1302
# Name: count, dtype: int64

# %%
gua_all
# Out:
# Index(['CodDepartamento', 'Departamento', 'CodMuni', 'Municipio', 'CodigoEst',
#        'NombreEstablecimiento', 'direccion', 'Tel', 'CorreoElectronico',
#        'Nivel', 'Jornada', 'Modalidad', 'Plan', 'Latitud', 'Longitud', 'Año',
#        'Sector', 'Area', 'school_level', 'is_cooperative'],
#       dtype='object')

# %%
gua_all = gua_all.rename(columns = {"CodigoEst": "deped_id"})
gua_all = gua_all[["deped_id", 'school_level', 'is_cooperative']]
gua_all.head()
# Out:
#         deped_id school_level  is_cooperative
# 0  00-01-0001-42  pre_primary           False
# 1  00-01-0002-42  pre_primary           False
# 3  00-01-0003-42  pre_primary           False
# 5  00-01-0004-42  pre_primary           False
# 7  00-01-0005-42  pre_primary           False

# %%
t = pd.merge(geo, gua_all, on = "deped_id")[["geo_id", "deped_id", "school_level", "is_cooperative"]]
# t["school_level_detail"] = None
# t["is_technical"] = None
t.head()
# Out:
#        geo_id       deped_id school_level  is_cooperative
# 0  GTM-000001  00-01-0001-42  pre_primary           False
# 1  GTM-000002  00-01-0002-42  pre_primary           False
# 2  GTM-000003  00-01-0003-42  pre_primary           False
# 3  GTM-000004  00-01-0004-42  pre_primary           False
# 4  GTM-000005  00-01-0005-42  pre_primary           False

# %%
t.
