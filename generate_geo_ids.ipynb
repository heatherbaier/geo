# %%
import pandas as pd
import os

# %% [markdown]
# Nigeria Educational Facilities

# %%
nig_ef = pd.read_csv("./data/nigeria/educational-facilities-in-nigeria.csv")
nig_ef = nig_ef[["facility_name"]]
nig_ef.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5fe32b9cd1e6> in <module>()
# ----> 1 nig_ef = pd.read_csv("/drive/MyDrive/GEO/GEO Fall 2022/data/nigeria/educational-facilities-in-nigeria.csv")
#       2 nig_ef = nig_ef[["facility_name"]]
#       3 nig_ef.head()
#
# NameError: name 'pd' is not defined

# %%
# Out:
# ['Ideas.gsheet',
#  'Untitled spreadsheet.gsheet',
#  'data',
#  'Data Procedures.gdoc',
#  'Untitled0.ipynb']
